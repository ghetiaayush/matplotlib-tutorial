# %%
# example 1
from numpy import *
from pylab import *
x = linspace(-3, 3, 30)
y = x**2
plot(x, y)
show()

# %%
# example 2
from pylab import *
x = linspace(-3, 3, 30)
y = x**2
plot(x, y, 'ro')
show()

# %%
from pylab import *
plot(x, sin(x))
plot(x, cos(x), 'r-')
plot(x, -sin(x), 'g--')
show()
